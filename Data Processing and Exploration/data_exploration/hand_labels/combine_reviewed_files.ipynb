# %%
import sklearn
import pandas as pd
import numpy as np
import nltk
import sklearn
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
import matplotlib
from sklearn.model_selection import cross_val_score
from scipy.stats import uniform as sp_randFloat
from scipy.stats import randint as sp_randInt
from sklearn.model_selection import train_test_split
import re
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
import pickle
from wordcloud import WordCloud

# %%
first_review_df = pd.read_excel('../../../datasafe/2031/full_hand_labelling_output_Apr_25_2023/full_reviewed_data/full_texts_to_label_Eva_export.xlsx')

# %%
first_review_df.drop(['label_id'], axis=1)
# Out:
#      text_id                                               text  \
# 0         60  Beloop: _x000D_\nPatiÃ«nte heeft 10 minuten va...
# 1         96  Beloop: _x000D_\nG5P4 36 wkGrav 1e lijnALL gee...
# 2         48  Conclusie: _x000D_\nNormale nacontrole. Kijkt ...
# 3         15  Beleid: _x000D_\nAlgemeen: Dagopname voor 3x P...
# 4         72                           Anamnese: _x000D_\n34W4D
# ..       ...                                                ...
# 495    14915  Indicatie:_x000D_\nZie aanvraag_x000D_\n_x000D...
# 496    15313  Anamnese: _x000D_\nAanvrager: Holterhues, C. (...
# 497    59430  Anamnese: _x000D_\nReden van aanmelding: Type:...
# 498    20411  Indicatie:_x000D_\nZie aanvraag_x000D_\n_x000D...
# 499     7881  Geachte collega,_x000D_\n_x000D_\n_x000D_\nBov...
#
#               Roken         Alcohol           Drugs
# 0    Niets gevonden  Niets gevonden  Niets gevonden
# 1    Niets gevonden  Niets gevonden  Niets gevonden
# 2    Niets gevonden  Niets gevonden  Niets gevonden
# 3    Niets gevonden  Niets gevonden  Niets gevonden
# 4    Niets gevonden  Niets gevonden  Niets gevonden
# ..              ...             ...             ...
# 495  Niets gevonden  Niets gevonden  Niets gevonden
# 496  Geen gebruiker  Geen gebruiker  Geen gebruiker
# 497  Niets gevonden  Niets gevonden  Niets gevonden
# 498  Niets gevonden  Niets gevonden  Niets gevonden
# 499  Niets gevonden  Niets gevonden  Niets gevonden
#
# [500 rows x 5 columns]

# %%
second_review_df = pd.read_excel('../../../datasafe/2031/full_hand_labelling_output_Apr_25_2023/full_reviewed_data/full_texts_to_label_random1_export.xlsx')

# %%
third_review_df = pd.read_excel('../../../datasafe/2031/full_hand_labelling_output_Apr_25_2023/full_reviewed_data/full_texts_to_label_random2_export.xlsx')

# %%
fourth_review_df = pd.read_excel('../../../datasafe/2031/full_hand_labelling_output_Apr_25_2023/full_reviewed_data/full_texts_to_label_random3_export.xlsx')

# %%
fifth_review_df = pd.read_excel('../../../datasafe/2031/full_hand_labelling_output_Apr_25_2023/full_reviewed_data/full_texts_to_label_Sietse_export.xlsx')

# %%
sixth_review_df = pd.read_excel('../../../datasafe/2031/full_hand_labelling_output_Apr_25_2023/full_reviewed_data/full_texts_to_label_top_Hielke_export.xlsx')

# %%
seventh_review_df = pd.read_excel('../../../datasafe/2031/full_hand_labelling_output_Apr_25_2023/full_reviewed_data/full_texts_to_label_full_previous_Hielke_export.xlsx')

# %%
fifth_review_df
# Out:
#      label_id  text_id                                               text  \
# 0         1.0       44  Samenvatting: _x000D_\nfeb 2019: vitrectomie +...
# 1         1.0        7  Beloop: _x000D_\nCONSULTENKAMERvia HAP ivm vag...
# 2         1.0       40  Anamnese: _x000D_\nHeeft plasklachten en in ur...
# 3         1.0       41  Samenvatting: _x000D_\n19/4/18: littekencorr e...
# 4         1.0       29  Anamnese: _x000D_\nvelkken zijn weg OS na nast...
# ..        ...      ...                                                ...
# 495       NaN    56909  Anamnese: _x000D_\nVerwijzing_x000D_\nVerdenki...
# 496       NaN    38108  Anamnese: _x000D_\nGeen klachten._x000D_\n_x00...
# 497       NaN    48246  Samenvatting: _x000D_\nDiabetes, pachy 545-585...
# 498       NaN    38334  Geachte heer Van Hessen,_x000D_\n_x000D_\nOp 0...
# 499       NaN    55413  Samenvatting: _x000D_\n06-2022: Cataractextrac...
#
#               Roken         Alcohol           Drugs
# 0    Niets gevonden  Niets gevonden  Niets gevonden
# 1    Niets gevonden  Niets gevonden  Niets gevonden
# 2    Niets gevonden  Niets gevonden  Niets gevonden
# 3    Niets gevonden  Niets gevonden  Niets gevonden
# 4    Niets gevonden  Niets gevonden  Niets gevonden
# ..              ...             ...             ...
# 495  Geen gebruiker  Geen gebruiker  Geen gebruiker
# 496  Niets gevonden  Niets gevonden  Niets gevonden
# 497  Niets gevonden  Niets gevonden  Niets gevonden
# 498  Niets gevonden  Niets gevonden  Niets gevonden
# 499  Niets gevonden  Niets gevonden  Niets gevonden
#
# [500 rows x 6 columns]

# %%
full_reviewed_data = pd.concat([first_review_df, second_review_df, 
                                third_review_df, fourth_review_df,
                               fifth_review_df, sixth_review_df, seventh_review_df])

# %%
full_reviewed_data_drop = full_reviewed_data.drop(['original_id', 'text_id'], axis=1)

# %%
full_reviewed_data_drop
# Out:
#     label_id                                               text  \
# 0        1.0  Beloop: _x000D_\nPatiÃ«nte heeft 10 minuten va...
# 1        1.0  Beloop: _x000D_\nG5P4 36 wkGrav 1e lijnALL gee...
# 2        1.0  Conclusie: _x000D_\nNormale nacontrole. Kijkt ...
# 3        1.0  Beleid: _x000D_\nAlgemeen: Dagopname voor 3x P...
# 4        1.0                           Anamnese: _x000D_\n34W4D
# ..       ...                                                ...
# 95       2.0  Beloop: _x000D_\nCONSULTENKAMERGezien door co-...
# 96       2.0  Reden van komst / Verwijzing: _x000D_\nReden v...
# 97       2.0  Beloop: _x000D_\nMR CPG7P4M4 //  MI: 4x sectio...
# 98       2.0  Reden van komst / Verwijzing: _x000D_\nReden v...
# 99       2.0  Reden van komst / Verwijzing: _x000D_\nReden v...
#
#              Roken         Alcohol           Drugs
# 0   Niets gevonden  Niets gevonden  Niets gevonden
# 1   Niets gevonden  Niets gevonden  Niets gevonden
# 2   Niets gevonden  Niets gevonden  Niets gevonden
# 3   Niets gevonden  Niets gevonden  Niets gevonden
# 4   Niets gevonden  Niets gevonden  Niets gevonden
# ..             ...             ...             ...
# 95  Geen gebruiker  Geen gebruiker  Geen gebruiker
# 96  Geen gebruiker  Geen gebruiker  Geen gebruiker
# 97  Geen gebruiker  Geen gebruiker  Geen gebruiker
# 98  Geen gebruiker  Geen gebruiker  Geen gebruiker
# 99  Geen gebruiker  Geen gebruiker  Geen gebruiker
#
# [4700 rows x 5 columns]

# %%
full_reviewed_data_drop.to_csv('../../input_data/full_datasets/fully_hand_labelled_texts.csv')
