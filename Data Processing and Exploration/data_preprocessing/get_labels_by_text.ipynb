# %%
import pandas as pd
import numpy as np
import csv
import re

# %%
full_haga_data = pd.read_csv('../../datasafe/2031/processed_data/processed_data/full_haga_data.csv')

# %%
full_haga_data
# Out:
#         Unnamed: 0                                 pseudo_id    cohort  \
# 0                0  000BD02193B45DAE2A6123C055EC87E113C518E3  Included
# 1                1  000FA25E78709D0CF3524FB98BF34B80AB4D63CE  Included
# 2                2  00109D742BA3424CEDE4130EDE0A95B56FF2F477  Included
# 3                3  001165F6D6FC7CF3D050729AE02CE7840969989D  Included
# 4                4  0012A0C4D87173293908E2C54DFECD0CD26565CA  Included
# ...            ...                                       ...       ...
# 237347       32795  FFFAFFFFC9DAC3A795AE05F7E898A491FF69522C  Included
# 237348       32796  FFFBA35DD7C92D587C7CF2AFB0962009D6A19B10  Included
# 237349       32797  FFFCCECF093378F735A62D86878AECE4851B012F  Included
# 237350       32798  FFFE68060E69BBCD2D2F4919DA3C833EEA5B0F15  Included
# 237351       32799  FFFED9C945583CAE323D4DB10B94067D104FFD2B  Included
#
#        roken_answer_label                           roken_report_tags  \
# 0          Niets gevonden  Radiologieverslag, Bekken/heup li, Heup li
# 1              Rookt niet                           Spoedeisende Hulp
# 2              Rookt niet                             Klinische Brief
# 3                  Rookte                         Poliklinische Brief
# 4              Rookt niet                         Poliklinische Brief
# ...                   ...                                         ...
# 237347             Rookte            Consult, Preoperatieve screening
# 237348         Rookt niet                         Poliklinische Brief
# 237349         Rookt niet        Consult, Polikliniek: eerste consult
# 237350     Niets gevonden                                     Consult
# 237351             Rookte            Consult, Preoperatieve screening
#
#                                      roken_report_content  \
# 0       Indicatie:\tX-bekken, x-heup axiaal \t\tKlinis...
# 1       -\tAankomst SEH: 23-02-2015  13:04\tIndicatie:...
# 2       Geachte collega,\t\tBovengenoemde patiënt was ...
# 3       Geachte collega,\t\tPoliklinisch zag ik uw pat...
# 4       Interne Geneeskunde\t\tReumatologie\t\t\t\t\tL...
# ...                                                   ...
# 237347  Anamnese: \t Verkort consult: Telefonisch cons...
# 237348  Geachte collega,\t\tMet bovengenoemde patiënte...
# 237349  Reden van komst / Verwijzing: \tReden verwijzi...
# 237350                                  Anamnese: \t11W4D
# 237351  Anamnese: \t Verkort consult: Aandachtspunten ...
#
#        roken_report_start_date alcohol_answer_label  \
# 0          2016-08-31 00:00:00       Niets gevonden
# 1          2015-02-23 00:00:00       Niets gevonden
# 2          2016-08-03 00:00:00       Niets gevonden
# 3          2015-05-04 00:00:00       Niets gevonden
# 4          2005-11-07 00:00:00                  Nee
# ...                        ...                  ...
# 237347     2022-09-22 09:11:00                   Ja
# 237348     2022-04-22 00:00:00       Niets gevonden
# 237349     2018-11-28 16:33:00       Niets gevonden
# 237350     2022-06-27 10:41:00       Niets gevonden
# 237351     2022-05-27 10:14:00       Niets gevonden
#
#                                alcohol_report_tags  \
# 0       Radiologieverslag, Bekken/heup li, Heup li
# 1                                  Klinische Brief
# 2                                         Algemeen
# 3                             Microbiologieverslag
# 4                     Consult, Telefonisch consult
# ...                                            ...
# 237347            Consult, Preoperatieve screening
# 237348                Consult, Telefonisch consult
# 237349                Consult, Telefonisch consult
# 237350                                     Consult
# 237351        Consult, Polikliniek: vervolgconsult
#
#                                    alcohol_report_content  \
# 0       Indicatie:\tX-bekken, x-heup axiaal \t\tKlinis...
# 1       Opnamedatum: 03-04-2016     \tOverleden op: [D...
# 2       Uw kenmerk:                011910023  \tOns ke...
# 3       UITSLAG MICROBIOLOGIE\t\t[INITIALS][LASTNAME] ...
# 4       Beloop: \tBeloop: TCHK: TC ivm second opinion,...
# ...                                                   ...
# 237347  Anamnese: \t Verkort consult: Telefonisch cons...
# 237348  Samenvatting: \tVoorgeschiedenis\tHypertensie\...
# 237349  Beloop: \tBeloop: Patiënt gesproken: nee\tVers...
# 237350                                  Anamnese: \t11W4D
# 237351  Samenvatting: \t22-06-2022 Ablatio mamma recht...
#
#        alcohol_report_start_date drugs_answer_label  \
# 0            2016-08-31 00:00:00     Niets gevonden
# 1            2016-04-05 00:00:00     Niets gevonden
# 2            2020-02-17 00:00:00                Nee
# 3            2017-10-20 13:14:00     Niets gevonden
# 4            2022-05-16 15:02:00     Niets gevonden
# ...                          ...                ...
# 237347       2022-09-22 09:11:00                Nee
# 237348       2023-01-26 09:16:00     Niets gevonden
# 237349       2022-11-09 11:12:00     Niets gevonden
# 237350       2022-06-27 10:41:00     Niets gevonden
# 237351       2023-01-31 10:36:00                Nee
#
#                                  drugs_report_tags  \
# 0       Radiologieverslag, Bekken/heup li, Heup li
# 1                                  Klinische Brief
# 2             Consult, Polikliniek: eerste consult
# 3                             Microbiologieverslag
# 4                       Radiologieverslag, Knie li
# ...                                            ...
# 237347            Consult, Preoperatieve screening
# 237348                Consult, Telefonisch consult
# 237349                Consult, Telefonisch consult
# 237350                                     Consult
# 237351            Consult, Preoperatieve screening
#
#                                      drugs_report_content  \
# 0       Indicatie:\tX-bekken, x-heup axiaal \t\tKlinis...
# 1       Opnamedatum: 03-04-2016     \tOverleden op: [D...
# 2       Anamnese: \tOp 29-08-2019 kopstaartbotsing geh...
# 3       UITSLAG MICROBIOLOGIE\t\t[INITIALS][LASTNAME] ...
# 4       Indicatie:\tZie ingescande aanvraag\t\tKlinish...
# ...                                                   ...
# 237347  Anamnese: \t Verkort consult: Telefonisch cons...
# 237348  Samenvatting: \tVoorgeschiedenis\tHypertensie\...
# 237349  Beloop: \tBeloop: Patiënt gesproken: nee\tVers...
# 237350                                  Anamnese: \t11W4D
# 237351  Anamnese: \t Verkort consult: Aandachtspunten ...
#
#        drugs_report_start_date
# 0          2016-08-31 00:00:00
# 1          2016-04-05 00:00:00
# 2          2019-10-23 14:34:00
# 3          2017-10-20 13:14:00
# 4          2022-12-17 00:00:00
# ...                        ...
# 237347     2022-09-22 09:11:00
# 237348     2023-01-26 09:16:00
# 237349     2022-11-09 11:12:00
# 237350     2022-06-27 10:41:00
# 237351     2022-05-27 10:14:00
#
# [237352 rows x 15 columns]

# %%
text_data = full_haga_data[['roken_report_content', 'roken_answer_label']]

# %%
text_data = text_data.drop_duplicates()

# %%
text_data_merged = text_data.merge(full_haga_data[['alcohol_report_content', 'alcohol_answer_label']], left_on='roken_report_content', right_on='alcohol_report_content', how='left')

# %%
text_data_merged_second = text_data_merged.merge(full_haga_data[['drugs_report_content', 'drugs_answer_label']], left_on='roken_report_content', right_on='drugs_report_content', how='left')

# %%
text_data_merged_second
# Out:
#                                      roken_report_content roken_answer_label  \
# 0       Indicatie:\tX-bekken, x-heup axiaal \t\tKlinis...     Niets gevonden
# 1       -\tAankomst SEH: 23-02-2015  13:04\tIndicatie:...         Rookt niet
# 2       Geachte collega,\t\tBovengenoemde patiënt was ...         Rookt niet
# 3       Geachte collega,\t\tPoliklinisch zag ik uw pat...             Rookte
# 4       Interne Geneeskunde\t\tReumatologie\t\t\t\t\tL...         Rookt niet
# ...                                                   ...                ...
# 652081  Anamnese: \t Verkort consult: Aandachtspunten ...             Rookte
# 652082  Samenvatting: \tVoorgeschiedenis: blanco.\tMed...     Niets gevonden
# 652083  Samenvatting: \t02-06: Ferrari <--> vRoosmalen...     Niets gevonden
# 652084  Samenvatting: \t12-2022 Pap 2 p2 c1 \t01-2023 ...         Rookt niet
# 652085                                  Anamnese: \t11W4D     Niets gevonden
#
#                                    alcohol_report_content  \
# 0       Indicatie:\tX-bekken, x-heup axiaal \t\tKlinis...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 652081  Anamnese: \t Verkort consult: Aandachtspunten ...
# 652082  Samenvatting: \tVoorgeschiedenis: blanco.\tMed...
# 652083                                                NaN
# 652084                                                NaN
# 652085                                  Anamnese: \t11W4D
#
#        alcohol_answer_label  \
# 0            Niets gevonden
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 652081                   Ja
# 652082       Niets gevonden
# 652083                  NaN
# 652084                  NaN
# 652085       Niets gevonden
#
#                                      drugs_report_content drugs_answer_label
# 0       Indicatie:\tX-bekken, x-heup axiaal \t\tKlinis...     Niets gevonden
# 1                                                     NaN                NaN
# 2                                                     NaN                NaN
# 3                                                     NaN                NaN
# 4                                                     NaN                NaN
# ...                                                   ...                ...
# 652081                                                NaN                NaN
# 652082  Samenvatting: \tVoorgeschiedenis: blanco.\tMed...     Niets gevonden
# 652083                                                NaN                NaN
# 652084                                                NaN                NaN
# 652085                                  Anamnese: \t11W4D     Niets gevonden
#
# [652086 rows x 6 columns]

# %%
full_labels = text_data_merged_second.drop(['alcohol_report_content', 'drugs_report_content'], axis=1).rename(columns={'roken_report_content': 'content'})

# %%
full_labels = full_labels.dropna().drop_duplicates()

# %%
full_labels.to_csv('../input_data/full_datasets/fully_labelled_texts.csv')
